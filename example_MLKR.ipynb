# %%
# License: BSD 3 clause
# Authors: Bhargav Srinivasa Desikan <bhargavvader@gmail.com>
#          William de Vazelhes <wdevazelhes@gmail.com>

# %%
import sys

from sklearn.manifold import TSNE

import metric_learn
import numpy as np
from sklearn.datasets import make_regression

# visualisation imports
import matplotlib.pyplot as plt
np.random.seed(42)

# %%
def plot_tsne(X, y, colormap=plt.cm.Paired):
    plt.figure(figsize=(8, 6))

    # clean the figure
    plt.clf()

    tsne = TSNE(learning_rate='auto', init='random')
    X_embedded = tsne.fit_transform(X)
    plt.scatter(X_embedded[:, 0], X_embedded[:, 1], c=y, cmap=colormap)

    plt.xticks(())
    plt.yticks(())

    plt.show()

# %%
X_reg, y_reg = make_regression(n_samples=100, n_informative=3, n_features=5,
                               shuffle=True)

# %%
plot_tsne(X_reg, y_reg, plt.cm.Oranges)

# %%
mlkr = metric_learn.MLKR(verbose=True)
X_mlkr = mlkr.fit_transform(X_reg, y_reg)
plot_tsne(X_mlkr, y_reg, plt.cm.Oranges)
# Out:
# [MLKR]
# [MLKR]  Iteration      Objective Value    Time(s)
# [MLKR] ------------------------------------------
# [MLKR]          0         1.270840e+05       0.00
# [MLKR]          1         2.587121e+04       0.00
# [MLKR]          2         2.223662e+04       0.00
# [MLKR]          3         1.624006e+04       0.00
# [MLKR]          4         1.367894e+04       0.00
# [MLKR]          5         1.214598e+04       0.00
# [MLKR]          6         1.132228e+04       0.00
# [MLKR]          7         1.028952e+04       0.00
# [MLKR]          8         9.607353e+03       0.00
# [MLKR]          9         9.070911e+03       0.00
# [MLKR]         10         8.950550e+03       0.00
# [MLKR]         11         8.787472e+03       0.00
# [MLKR]         12         8.615681e+03       0.00
# [MLKR]         13         8.231782e+03       0.00
# [MLKR]         14         8.079728e+03       0.00
# [MLKR]         15         7.961603e+03       0.00
# [MLKR]         16         7.896829e+03       0.00
# [MLKR]         17         7.854719e+03       0.00
# [MLKR]         18         7.822262e+03       0.00
# [MLKR]         19         7.773632e+03       0.00
# [MLKR]         20         7.683600e+03       0.00
# [MLKR]         21         7.565193e+03       0.00
# [MLKR]         22         7.505810e+03       0.00
# [MLKR]         23         7.444963e+03       0.00
# [MLKR]         24         7.411311e+03       0.00
# [MLKR]         25         7.382705e+03       0.00
# [MLKR]         26         7.370505e+03       0.00
# [MLKR]         27         7.361111e+03       0.03
# [MLKR]         28         7.356933e+03       0.00
# [MLKR]         29         7.353371e+03       0.00
# [MLKR]         30         7.350556e+03       0.00
# [MLKR]         31         7.347080e+03       0.01
# [MLKR]         32         7.344438e+03       0.02
# [MLKR]         33         7.340096e+03       0.01
# [MLKR]         34         7.338442e+03       0.00
# [MLKR]         35         7.337572e+03       0.00
# [MLKR]         36         7.337343e+03       0.00
# [MLKR]         37         7.337284e+03       0.00
# [MLKR]         38         7.337238e+03       0.01
# [MLKR]         39         7.337231e+03       0.00
# [MLKR]         40         7.337209e+03       0.00
# [MLKR]         41         7.337202e+03       0.00
# [MLKR]         42         7.337196e+03       0.00
# [MLKR]         43         7.337192e+03       0.00
# [MLKR]         44         7.337187e+03       0.00
# [MLKR]         45         7.337187e+03       0.01
# [MLKR]         46         7.337186e+03       0.01
# [MLKR]         47         7.337186e+03       0.00
# [MLKR]         48         7.337186e+03       0.01
# [MLKR]         49         7.337186e+03       0.00
# [MLKR]         50         7.337186e+03       0.00
# [MLKR]         51         7.337186e+03       0.00
# [MLKR]         52         7.337186e+03       0.00
# [MLKR] Training took     0.32s.
